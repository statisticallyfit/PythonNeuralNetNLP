# %%
import os
from typing import *


os.getcwd()
# Setting the baseline:
os.chdir('/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP')


curPath: str = os.getcwd() + "/src/VisualGraphStudy/"

dataPath: str = curPath + "_data/"


print("curPath = ", curPath, "\n")
print("dataPath = ", dataPath, "\n")
# Out:
# curPath =  /development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/VisualGraphStudy/
#
# dataPath =  /development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/VisualGraphStudy/_data/

# %%
import sys
# Making files in utils folder visible here: to import my local print functions for nn.Module objects
sys.path.append(os.getcwd() + "/src/utils/")
# For being able to import files within CausalNex folder
sys.path.append(curPath)
sys.path.append(curPath + 'fonts/')

sys.path
# Out:
# ['/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/VisualGraphStudy',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python37.zip',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7/lib-dynload',
#  '',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7/site-packages',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7/site-packages/IPython/extensions',
#  '/home/statisticallyfit/.ipython',
#  '/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/utils/',
#  '/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/VisualGraphStudy/',
#  '/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/VisualGraphStudy/fonts/']

# %% [markdown]
# Fitting node states, using the input data:

# %%
import pandas as pd
from pandas.core.frame import DataFrame

from src.utils.DataUtil import *

CPD_workCapacity: DataFrame = pd.read_csv(dataPath + 'cpd_workcapacity.csv', delimiter =',')
CPD_workCapacity
# Out:
#     Time ExertionLevel ExperienceLevel TrainingLevel    Low  High
# 0      1           Low             Low           Low   0.01    99
# 1      1           Low             Low          High  20.00    80
# 2      1           Low            High           Low  15.00    85
# 3      1           Low            High          High   2.00    98
# 4      1          High             Low           Low  90.00    10
# 5      1          High             Low          High  60.00    40
# 6      1          High            High           Low  19.00    81
# 7      1          High            High          High  11.00    89
# 8      2           Low             Low           Low  31.00    69
# 9      2           Low             Low          High  21.00    79
# 10     2           Low            High           Low  15.00    85
# 11     2           Low            High          High   2.00    98
# 12     2          High             Low           Low  90.00    10
# 13     2          High             Low          High  61.00    39
# 14     2          High            High           Low  11.00    89
# 15     2          High            High          High  12.00    88
# 16     3           Low             Low           Low  31.00    69
# 17     3           Low             Low          High  21.00    79
# 18     3           Low            High           Low  16.00    84
# 19     3           Low            High          High   3.00    97
# 20     3          High             Low           Low  91.00     9
# 21     3          High             Low          High  60.00    40
# 22     3          High            High           Low  16.00    84
# 23     3          High            High          High  15.00    85
# 24     4           Low             Low           Low  32.00    68
# 25     4           Low             Low          High  22.00    78
# 26     4           Low            High           Low  16.00    84
# 27     4           Low            High          High   3.00    97
# 28     4          High             Low           Low  91.00     9
# 29     4          High             Low          High  62.00    38
# 30     4          High            High           Low  19.00    81
# 31     4          High            High          High  13.00    87
# 32     5           Low             Low           Low  33.00    67
# 33     5           Low             Low          High  25.00    75
# 34     5           Low            High           Low  17.00    83
# 35     5           Low            High          High   4.00    96
# 36     5          High             Low           Low  92.00     8
# 37     5          High             Low          High  69.00    31
# 38     5          High            High           Low  18.00    82
# 39     5          High            High          High  17.00    83

# %%
CPD_exertionLevel: DataFrame = pd.read_csv(dataPath + 'cpd_exertion_experience_training.csv', delimiter =',').dropna()
CPD_experienceLevel = CPD_exertionLevel.copy()
CPD_trainingLevel = CPD_exertionLevel.copy()

CPD_exertionLevel
# Out:
#    Low  High
# 0   50    50

# %%
CPD_injuryType: DataFrame = pd.read_csv(dataPath + 'cpd_injurytype.csv', delimiter =',').dropna()

CPD_injuryType
# Out:
#          ProcessType           UsesOps  Chemical-Burn  Electrical-Burn  \
# 0        Accel-Pedal          Forklift           20.0             20.0
# 1        Accel-Pedal  Front-Right-Door           20.0             20.0
# 2        Accel-Pedal               Oil           20.0             20.0
# 3        Accel-Pedal         Power-Gun            1.0             40.0
# 4         Door-Mount          Forklift            1.0              8.0
# 5         Door-Mount  Front-Right-Door            1.0              7.0
# 6         Door-Mount               Oil           43.0             33.0
# 7         Door-Mount         Power-Gun            2.5              2.5
# 8       Engine-Mount          Forklift            1.0              8.0
# 9       Engine-Mount  Front-Right-Door            1.0              8.0
# 10      Engine-Mount               Oil           22.0             33.0
# 11      Engine-Mount         Power-Gun            5.0             35.0
# 12     Engine-Wiring          Forklift            3.0              8.0
# 13     Engine-Wiring  Front-Right-Door            1.0              8.0
# 14     Engine-Wiring               Oil           22.0             33.0
# 15     Engine-Wiring         Power-Gun            5.0             35.0
# 16          Oil-Fill          Forklift            0.0              1.0
# 17          Oil-Fill  Front-Right-Door            0.0             10.0
# 18          Oil-Fill               Oil            0.0             50.0
# 19          Oil-Fill         Power-Gun            0.0             40.0
# 20  Sun-Roof-Housing          Forklift            0.0              0.0
# 21  Sun-Roof-Housing  Front-Right-Door            0.0              0.0
# 22  Sun-Roof-Housing               Oil           20.0             30.0
# 23  Sun-Roof-Housing         Power-Gun           20.0             30.0
#
#     Electrical-Shock  Contact-Contusion  FallGtm
# 0                 20               20.0     20.0
# 1                 20               20.0     20.0
# 2                 20               20.0     20.0
# 3                 57                1.0      1.0
# 4                  1               80.0     10.0
# 5                  2               75.0     15.0
# 6                 22                1.0      1.0
# 7                 90                2.5      2.5
# 8                  1               80.0     10.0
# 9                  1               80.0     10.0
# 10                43                1.0      1.0
# 11                60                0.0      0.0
# 12                 5               79.0      5.0
# 13                 1               80.0     10.0
# 14                45                0.0      0.0
# 15                60                0.0      0.0
# 16                 4               70.0     25.0
# 17                10               80.0      0.0
# 18                50                0.0      0.0
# 19                60                0.0      0.0
# 20                 0               40.0     60.0
# 21                 0               70.0     30.0
# 22                50                0.0      0.0
# 23                50                0.0      0.0

# %%
CPD_processType: DataFrame = pd.read_csv(dataPath + 'cpd_processtype.csv', delimiter =',').dropna()
CPD_processType
# Out:
#    Accel-Pedal  Door-Mount  Engine-Mount  Engine-Wiring  Oil-Fill  \
# 0       16.667      16.667        16.667         16.667    16.667
#
#    Sun-Roof-Housing
# 0            16.667

# %%
CPD_time: DataFrame = pd.read_csv(dataPath + 'cpd_time.csv', delimiter =',').dropna()

CPD_time
# Out:
#     1   2   3   4   5
# 0  20  20  20  20  20

# %%
CPD_usesop: DataFrame = pd.read_csv(dataPath + 'cpd_usesop.csv', delimiter =',').dropna()

CPD_usesop
# Out:
#         ProcessType  Forklift  Front-Right-Door  Oil  Power-Gun
# 0       Accel-Pedal         1                 7    2         90
# 1        Door-Mount         4                90    1          5
# 2      Engine-Mount        95                 1    1          3
# 3     Engine-Wiring         1                 1    1         97
# 4          Oil-Fill         0                 0  100          0
# 5  Sun-Roof-Housing        94                 1    3          2

# %%
CPD_absentee: DataFrame = pd.read_csv(dataPath + 'cpd_absentee.csv', delimiter =',').dropna()
CPD_absentee
# Out:
#      Time       ProcessType         InjuryType WorkCapacity   Low  High
# 0       1       Accel-Pedal      Chemical-Burn          Low  70.0  30.0
# 1       1       Accel-Pedal      Chemical-Burn         High  90.0  10.0
# 2       1       Accel-Pedal    Electrical-Burn          Low  60.0  40.0
# 3       1       Accel-Pedal    Electrical-Burn         High  80.0  20.0
# 4       1       Accel-Pedal   Electrical-Shock          Low  70.0  30.0
# ..    ...               ...                ...          ...   ...   ...
# 295     5  Sun-Roof-Housing   Electrical-Shock         High  94.0   6.0
# 296     5  Sun-Roof-Housing  Contact-Contusion          Low   1.0  99.0
# 297     5  Sun-Roof-Housing  Contact-Contusion         High   2.0  98.0
# 298     5  Sun-Roof-Housing            FallGtm          Low   1.0  99.0
# 299     5  Sun-Roof-Housing            FallGtm         High   2.0  98.0
#
# [300 rows x 6 columns]

# %%
# Build model now with pgmpy
from pgmpy.models import BayesianModel

from src.utils.GraphvizUtil import *

# Defining model structure, just by passing a list of edges.
carModel: BayesianModel = BayesianModel([('Time', 'WorkCapacity'), ('TrainingLevel', 'WorkCapacity'),
                                         ('ExperienceLevel', 'WorkCapacity'), ('ExertionLevel', 'WorkCapacity'),
                                         ('Time', 'AbsenteeismLevel'),
                                         ('ProcessType', 'UsesOps'), ('ProcessType', 'InjuryType'), ('ProcessType',
                                                                                                     'AbsenteeismLevel'),
                                         ('UsesOps', 'InjuryType'), ('InjuryType', 'AbsenteeismLevel'),
                                         ('WorkCapacity', 'AbsenteeismLevel')])
#model: BayesianModel = BayesianModel([('Difficulty', 'Grade'), ('Intelligence', 'Grade'), ('Grade', 'Letter'), ('Intelligence', 'SAT')])

pgmpyToGraph(model  = carModel)

# %%
# Next: convert the DataFrames (pandas) into TabularCPDS (pgmpy)

# %%
from pgmpy.factors.discrete.CPD import TabularCPD


def dataframeToTabularCPD(variable: Variable, cardinality: int,
                          dataframe: DataFrame, convertFromPercent: bool = True) -> TabularCPD:
    '''
    Convert pandas.DataFrame to pgmpy TabularCPD
    Arguments:
        variable: name of the variable for which we build the CPD object
        cardinality: the number of states that the variable takes on, assumed to occur in the last `numStates` column of this dataframe. (So if number of state is 3, like 'Low', 'High', "Medium", then we assume these are the last 3 columns)
        dataframe: the pandas dataframe, structured as in the above examples
    Returns:
        TabularCPD object with values transferred from DataFrame.
    '''
    # Using this function to get  the index where the conditional variable names end and where the `variable` state names begin. Assuming the CPD values are floats so we can distinguish where they are.
    #def indexOfFirstFloat(vals: List) -> int:
    #    for index, value in list(zip(range(0, len(vals)), vals)):
    #        if type(value) == float:
    #            return index # get index of first float

    # Get number of conditional variables
    numCondVars: int = len(dataframe.columns) - cardinality
    #numCondVars: int = indexOfFirstFloat(dataframe.values[0]) # using the first row

    # Get number of states of the given variable
    #varCardinality: int = len(dataframe.columns) - numCondVars


    # Getting the names of the conditional variables
    condVars: List[Variable] = dataframe.columns[0 : numCondVars]

    # Getting the cardinalities of each of the conditional variables
    condCardinalities: List[int] = [len(np.unique(dataframe[evidenceVar])) for evidenceVar in condVars]

    # Getting the actual numbers (CPD values)
    rawCPDValues: List[List[float]] = dataframe.values.T[numCondVars:].T

    if convertFromPercent:
        # Converting, since they are in percent format (convert into probability format, so 0 < p < 1)
        rawCPDValues = list(map(lambda percentProbList : list(percentProbList / 100.0), rawCPDValues))

    # Maps to the conditional variable names and the list of their states
    condStatesTuples = [(evidenceVar, list(np.unique(dataframe[evidenceVar]))) for evidenceVar in condVars]

    # Get the actual states of the variable
    varStates: List[State] = list(dataframe.columns[numCondVars:])

    # Single map from the given variable name to its states
    varStatesTuples = [(variable, varStates)]

    # Combining above information to create the dictionary of state names for the variable
    stateNames: Dict[Variable, List[State]] = dict(varStatesTuples + condStatesTuples)

    # Now finally constructing the object:
    tabularCPD = TabularCPD(variable = variable, variable_card = cardinality,
                            values = rawCPDValues,
                            evidence = condVars, evidence_card = condCardinalities,
                            state_names = stateNames)

    return tabularCPD

# %%
cpd_usesop: TabularCPD = dataframeToTabularCPD(variable = 'UsesOps', cardinality = 4, dataframe = CPD_usesop)
cpd_process: TabularCPD = dataframeToTabularCPD(variable = 'ProcessType', cardinality = 6, dataframe = CPD_processType)
cpd_injury: TabularCPD = dataframeToTabularCPD(variable = 'InjuryType', cardinality = 5, dataframe = CPD_injuryType)
cpd_time: TabularCPD = dataframeToTabularCPD(variable = 'Time', cardinality = 5, dataframe = CPD_time)
cpd_exertion: TabularCPD = dataframeToTabularCPD(variable = 'ExertionLevel', cardinality = 2, dataframe = CPD_exertionLevel)
cpd_experience: TabularCPD = dataframeToTabularCPD(variable = 'ExperienceLevel', cardinality = 2, dataframe = CPD_experienceLevel)
cpd_training: TabularCPD = dataframeToTabularCPD(variable = 'TrainingLevel', cardinality = 2, dataframe = CPD_trainingLevel)
cpd_workcapacity: TabularCPD = dataframeToTabularCPD(variable = 'WorkCapacity', cardinality = 2, dataframe = CPD_workCapacity)
cpd_absentee: TabularCPD = dataframeToTabularCPD(variable = 'AbsenteeismLevel', cardinality = 2, dataframe = CPD_absentee)


carModel.add_cpds(cpd_usesop, cpd_process, cpd_injury, cpd_time, cpd_exertion, cpd_experience, cpd_training, cpd_workcapacity, cpd_absentee)

#assert carModel.check_model() # TODO says sum of CPDs is not equal to 1 for WorkCapacity (atol=0.01 in is_valid_cpd() too low???)

# %%
pgmpyToGraph(carModel)

# %%
pgmpyToGrid(carModel, 'AbsenteeismLevel') # assert it is the same as CPD_absenteeism.get_values()
# Out:
# [[1, 'Accel-Pedal', 'Chemical-Burn', 'High', 0.7, 0.88],
#  [1, 'Accel-Pedal', 'Chemical-Burn', 'Low', 0.3, 0.12],
#  [1, 'Accel-Pedal', 'Contact-Contusion', 'High', 0.9, 0.9],
#  [1, 'Accel-Pedal', 'Contact-Contusion', 'Low', 0.1, 0.1],
#  [1, 'Accel-Pedal', 'Electrical-Burn', 'High', 0.6, 0.157],
#  [1, 'Accel-Pedal', 'Electrical-Burn', 'Low', 0.4, 0.843],
#  [1, 'Accel-Pedal', 'Electrical-Shock', 'High', 0.8, 0.25],
#  [1, 'Accel-Pedal', 'Electrical-Shock', 'Low', 0.2, 0.75],
#  [1, 'Accel-Pedal', 'FallGtm', 'High', 0.7, 0.182],
#  [1, 'Accel-Pedal', 'FallGtm', 'Low', 0.3, 0.818],
#  [1, 'Door-Mount', 'Chemical-Burn', 'High', 0.8, 0.2],
#  [1, 'Door-Mount', 'Chemical-Burn', 'Low', 0.2, 0.8],
#  [1, 'Door-Mount', 'Contact-Contusion', 'High', 0.69, 0.8998999999999999],
#  [1, 'Door-Mount', 'Contact-Contusion', 'Low', 0.31, 0.1001],
#  [1, 'Door-Mount', 'Electrical-Burn', 'High', 0.89, 1.0],
#  [1, 'Door-Mount', 'Electrical-Burn', 'Low', 0.11, 0.0],
#  [1, 'Door-Mount', 'Electrical-Shock', 'High', 0.84, 0.95],
#  [1, 'Door-Mount', 'Electrical-Shock', 'Low', 0.16, 0.05],
#  [1, 'Door-Mount', 'FallGtm', 'High', 0.94, 1.0],
#  [1, 'Door-Mount', 'FallGtm', 'Low', 0.06, 0.0],
#  [1, 'Engine-Mount', 'Chemical-Burn', 'High', 0.8, 0.07],
#  [1, 'Engine-Mount', 'Chemical-Burn', 'Low', 0.2, 0.93],
#  [1, 'Engine-Mount', 'Contact-Contusion', 'High', 0.9, 0.1],
#  [1, 'Engine-Mount', 'Contact-Contusion', 'Low', 0.1, 0.9],
#  [1, 'Engine-Mount', 'Electrical-Burn', 'High', 0.8, 0.057800000000000004],
#  [1, 'Engine-Mount', 'Electrical-Burn', 'Low', 0.2, 0.9422],
#  [1, 'Engine-Mount', 'Electrical-Shock', 'High', 0.9, 0.1],
#  [1, 'Engine-Mount', 'Electrical-Shock', 'Low', 0.1, 0.9],
#  [1, 'Engine-Mount', 'FallGtm', 'High', 0.8, 0.08900000000000001],
#  [1, 'Engine-Mount', 'FallGtm', 'Low', 0.2, 0.9109999999999999],
#  [1, 'Engine-Wiring', 'Chemical-Burn', 'High', 0.9, 0.1],
#  [1, 'Engine-Wiring', 'Chemical-Burn', 'Low', 0.1, 0.9],
#  [1, 'Engine-Wiring', 'Contact-Contusion', 'High', 0.04, 0.945],
#  [1, 'Engine-Wiring', 'Contact-Contusion', 'Low', 0.96, 0.055],
#  [1, 'Engine-Wiring', 'Electrical-Burn', 'High', 0.1, 1.0],
#  [1, 'Engine-Wiring', 'Electrical-Burn', 'Low', 0.9, 0.0],
#  [1, 'Engine-Wiring', 'Electrical-Shock', 'High', 0.02, 0.9555],
#  [1, 'Engine-Wiring', 'Electrical-Shock', 'Low', 0.98, 0.044500000000000005],
#  [1, 'Engine-Wiring', 'FallGtm', 'High', 0.05, 1.0],
#  [1, 'Engine-Wiring', 'FallGtm', 'Low', 0.95, 0.0],
#  [1, 'Oil-Fill', 'Chemical-Burn', 'High', 0.8, 0.9111100000000001],
#  [1, 'Oil-Fill', 'Chemical-Burn', 'Low', 0.2, 0.08889],
#  [1, 'Oil-Fill', 'Contact-Contusion', 'High', 0.9, 0.95],
#  [1, 'Oil-Fill', 'Contact-Contusion', 'Low', 0.1, 0.05],
#  [1, 'Oil-Fill', 'Electrical-Burn', 'High', 0.15, 0.897],
#  [1, 'Oil-Fill', 'Electrical-Burn', 'Low', 0.85, 0.10300000000000001],
#  [1, 'Oil-Fill', 'Electrical-Shock', 'High', 0.25, 0.95],
#  [1, 'Oil-Fill', 'Electrical-Shock', 'Low', 0.75, 0.05],
#  [1, 'Oil-Fill', 'FallGtm', 'High', 0.1, 0.879],
#  [1, 'Oil-Fill', 'FallGtm', 'Low', 0.9, 0.121],
#  [1, 'Sun-Roof-Housing', 'Chemical-Burn', 'High', 0.2, 0.95],
#  [1, 'Sun-Roof-Housing', 'Chemical-Burn', 'Low', 0.8, 0.05],
#  [1, 'Sun-Roof-Housing', 'Contact-Contusion', 'High', 0.25, 0.034],
#  [1, 'Sun-Roof-Housing', 'Contact-Contusion', 'Low', 0.75, 0.966],
#  [1, 'Sun-Roof-Housing', 'Electrical-Burn', 'High', 0.4, 0.05],
#  [1, 'Sun-Roof-Housing', 'Electrical-Burn', 'Low', 0.6, 0.95],
#  [1, 'Sun-Roof-Housing', 'Electrical-Shock', 'High', 0.3, 0.032],
#  [1, 'Sun-Roof-Housing', 'Electrical-Shock', 'Low', 0.7, 0.968],
#  [1, 'Sun-Roof-Housing', 'FallGtm', 'High', 0.4, 0.05],
#  [1, 'Sun-Roof-Housing', 'FallGtm', 'Low', 0.6, 0.95],
#  [2, 'Accel-Pedal', 'Chemical-Burn', 'High', 0.85, 0.9112299999999999],
#  [2, 'Accel-Pedal', 'Chemical-Burn', 'Low', 0.15, 0.08877],
#  [2, 'Accel-Pedal', 'Contact-Contusion', 'High', 0.9, 0.96],
#  [2, 'Accel-Pedal', 'Contact-Contusion', 'Low', 0.1, 0.04],
#  [2, 'Accel-Pedal', 'Electrical-Burn', 'High', 0.1, 0.8043300000000001],
#  [2, 'Accel-Pedal', 'Electrical-Burn', 'Low', 0.9, 0.19567],
#  [2, 'Accel-Pedal', 'Electrical-Shock', 'High', 0.25, 0.8540000000000001],
#  [2, 'Accel-Pedal', 'Electrical-Shock', 'Low', 0.75, 0.146],
#  [2, 'Accel-Pedal', 'FallGtm', 'High', 0.1, 0.802],
#  [2, 'Accel-Pedal', 'FallGtm', 'Low', 0.9, 0.198],
#  [2, 'Door-Mount', 'Chemical-Burn', 'High', 0.2, 0.87],
#  [2, 'Door-Mount', 'Chemical-Burn', 'Low', 0.8, 0.13],
#  [2, 'Door-Mount', 'Contact-Contusion', 'High', 0.9, 0.9333],
#  [2, 'Door-Mount', 'Contact-Contusion', 'Low', 0.1, 0.0667],
#  [2, 'Door-Mount', 'Electrical-Burn', 'High', 1.0, 1.0],
#  [2, 'Door-Mount', 'Electrical-Burn', 'Low', 0.0, 0.0],
#  [2, 'Door-Mount', 'Electrical-Shock', 'High', 0.9, 0.95],
#  [2, 'Door-Mount', 'Electrical-Shock', 'Low', 0.1, 0.05],
#  [2, 'Door-Mount', 'FallGtm', 'High', 1.0, 1.0],
#  [2, 'Door-Mount', 'FallGtm', 'Low', 0.0, 0.0],
#  [2, 'Engine-Mount', 'Chemical-Burn', 'High', 0.05, 0.8945000000000001],
#  [2, 'Engine-Mount', 'Chemical-Burn', 'Low', 0.95, 0.10550000000000001],
#  [2, 'Engine-Mount', 'Contact-Contusion', 'High', 0.1, 0.94],
#  [2, 'Engine-Mount', 'Contact-Contusion', 'Low', 0.9, 0.06],
#  [2, 'Engine-Mount', 'Electrical-Burn', 'High', 0.05, 0.9],
#  [2, 'Engine-Mount', 'Electrical-Burn', 'Low', 0.95, 0.1],
#  [2, 'Engine-Mount', 'Electrical-Shock', 'High', 0.1, 0.93],
#  [2, 'Engine-Mount', 'Electrical-Shock', 'Low', 0.9, 0.07],
#  [2, 'Engine-Mount', 'FallGtm', 'High', 0.04, 0.922],
#  [2, 'Engine-Mount', 'FallGtm', 'Low', 0.96, 0.078],
#  [2, 'Engine-Wiring', 'Chemical-Burn', 'High', 0.1, 0.97],
#  [2, 'Engine-Wiring', 'Chemical-Burn', 'Low', 0.9, 0.03],
#  [2, 'Engine-Wiring', 'Contact-Contusion', 'High', 0.82, 0.023399999999999997],
#  [2, 'Engine-Wiring', 'Contact-Contusion', 'Low', 0.18, 0.9765999999999999],
#  [2, 'Engine-Wiring', 'Electrical-Burn', 'High', 0.87, 0.05],
#  [2, 'Engine-Wiring', 'Electrical-Burn', 'Low', 0.13, 0.95],
#  [2, 'Engine-Wiring', 'Electrical-Shock', 'High', 0.8, 0.015600000000000001],
#  [2, 'Engine-Wiring', 'Electrical-Shock', 'Low', 0.2, 0.9843999999999999],
#  [2, 'Engine-Wiring', 'FallGtm', 'High', 0.88, 0.02],
#  [2, 'Engine-Wiring', 'FallGtm', 'Low', 0.12, 0.98],
#  [2, 'Oil-Fill', 'Chemical-Burn', 'High', 0.9, 0.897],
#  [2, 'Oil-Fill', 'Chemical-Burn', 'Low', 0.1, 0.10300000000000001],
#  [2, 'Oil-Fill', 'Contact-Contusion', 'High', 0.95, 0.93],
#  [2, 'Oil-Fill', 'Contact-Contusion', 'Low', 0.05, 0.07],
#  [2, 'Oil-Fill', 'Electrical-Burn', 'High', 0.9, 0.122],
#  [2, 'Oil-Fill', 'Electrical-Burn', 'Low', 0.1, 0.878],
#  [2, 'Oil-Fill', 'Electrical-Shock', 'High', 0.95, 0.13],
#  [2, 'Oil-Fill', 'Electrical-Shock', 'Low', 0.05, 0.87],
#  [2, 'Oil-Fill', 'FallGtm', 'High', 0.85, 0.113],
#  [2, 'Oil-Fill', 'FallGtm', 'Low', 0.15, 0.887],
#  [2, 'Sun-Roof-Housing', 'Chemical-Burn', 'High', 0.95, 0.12],
#  [2, 'Sun-Roof-Housing', 'Chemical-Burn', 'Low', 0.05, 0.88],
#  [2, 'Sun-Roof-Housing', 'Contact-Contusion', 'High', 0.02, 0.315],
#  [2, 'Sun-Roof-Housing', 'Contact-Contusion', 'Low', 0.98, 0.685],
#  [2, 'Sun-Roof-Housing', 'Electrical-Burn', 'High', 0.05, 0.33],
#  [2, 'Sun-Roof-Housing', 'Electrical-Burn', 'Low', 0.95, 0.67],
#  [2, 'Sun-Roof-Housing', 'Electrical-Shock', 'High', 0.03, 0.1945],
#  [2, 'Sun-Roof-Housing', 'Electrical-Shock', 'Low', 0.97, 0.8055],
#  [2, 'Sun-Roof-Housing', 'FallGtm', 'High', 0.05, 0.22],
#  [2, 'Sun-Roof-Housing', 'FallGtm', 'Low', 0.95, 0.78],
#  [3, 'Accel-Pedal', 'Chemical-Burn', 'High', 0.97, 0.9455500000000001],
#  [3, 'Accel-Pedal', 'Chemical-Burn', 'Low', 0.03, 0.054450000000000005],
#  [3, 'Accel-Pedal', 'Contact-Contusion', 'High', 0.99, 0.98],
#  [3, 'Accel-Pedal', 'Contact-Contusion', 'Low', 0.01, 0.02],
#  [3, 'Accel-Pedal', 'Electrical-Burn', 'High', 0.11, 0.11],
#  [3, 'Accel-Pedal', 'Electrical-Burn', 'Low', 0.89, 0.89],
#  [3, 'Accel-Pedal', 'Electrical-Shock', 'High', 0.2, 0.12],
#  [3, 'Accel-Pedal', 'Electrical-Shock', 'Low', 0.8, 0.88],
#  [3, 'Accel-Pedal', 'FallGtm', 'High', 0.03, 0.15],
#  [3, 'Accel-Pedal', 'FallGtm', 'Low', 0.97, 0.85],
#  [3, 'Door-Mount', 'Chemical-Burn', 'High', 0.05, 0.17],
#  [3, 'Door-Mount', 'Chemical-Burn', 'Low', 0.95, 0.83],
#  [3, 'Door-Mount', 'Contact-Contusion', 'High', 0.8, 0.903],
#  [3, 'Door-Mount', 'Contact-Contusion', 'Low', 0.2, 0.09699999999999999],
#  [3, 'Door-Mount', 'Electrical-Burn', 'High', 0.9, 1.0],
#  [3, 'Door-Mount', 'Electrical-Burn', 'Low', 0.1, 0.0],
#  [3, 'Door-Mount', 'Electrical-Shock', 'High', 0.94, 0.9540000000000001],
#  [3, 'Door-Mount', 'Electrical-Shock', 'Low', 0.06, 0.046],
#  [3, 'Door-Mount', 'FallGtm', 'High', 0.98, 1.0],
#  [3, 'Door-Mount', 'FallGtm', 'Low', 0.02, 0.0],
#  [3, 'Engine-Mount', 'Chemical-Burn', 'High', 0.85, 0.025],
#  [3, 'Engine-Mount', 'Chemical-Burn', 'Low', 0.15, 0.975],
#  [3, 'Engine-Mount', 'Contact-Contusion', 'High', 0.9, 0.032],
#  [3, 'Engine-Mount', 'Contact-Contusion', 'Low', 0.1, 0.968],
#  [3, 'Engine-Mount', 'Electrical-Burn', 'High', 0.85, 0.011000000000000001],
#  [3, 'Engine-Mount', 'Electrical-Burn', 'Low', 0.15, 0.9890000000000001],
#  [3, 'Engine-Mount', 'Electrical-Shock', 'High', 0.9, 0.02],
#  [3, 'Engine-Mount', 'Electrical-Shock', 'Low', 0.1, 0.98],
#  [3, 'Engine-Mount', 'FallGtm', 'High', 0.75, 0.03],
#  [3, 'Engine-Mount', 'FallGtm', 'Low', 0.25, 0.97],
#  [3, 'Engine-Wiring', 'Chemical-Burn', 'High', 0.9, 0.04],
#  [3, 'Engine-Wiring', 'Chemical-Burn', 'Low', 0.1, 0.96],
#  [3, 'Engine-Wiring', 'Contact-Contusion', 'High', 0.08, 0.9],
#  [3, 'Engine-Wiring', 'Contact-Contusion', 'Low', 0.92, 0.1],
#  [3, 'Engine-Wiring', 'Electrical-Burn', 'High', 0.1, 1.0],
#  [3, 'Engine-Wiring', 'Electrical-Burn', 'Low', 0.9, 0.0],
#  [3, 'Engine-Wiring', 'Electrical-Shock', 'High', 0.02, 0.9],
#  [3, 'Engine-Wiring', 'Electrical-Shock', 'Low', 0.98, 0.1],
#  [3, 'Engine-Wiring', 'FallGtm', 'High', 0.05, 1.0],
#  [3, 'Engine-Wiring', 'FallGtm', 'Low', 0.95, 0.0],
#  [3, 'Oil-Fill', 'Chemical-Burn', 'High', 0.81, 0.94],
#  [3, 'Oil-Fill', 'Chemical-Burn', 'Low', 0.19, 0.06],
#  [3, 'Oil-Fill', 'Contact-Contusion', 'High', 0.9, 0.97],
#  [3, 'Oil-Fill', 'Contact-Contusion', 'Low', 0.1, 0.03],
#  [3, 'Oil-Fill', 'Electrical-Burn', 'High', 0.1, 0.94],
#  [3, 'Oil-Fill', 'Electrical-Burn', 'Low', 0.9, 0.06],
#  [3, 'Oil-Fill', 'Electrical-Shock', 'High', 0.25, 0.99],
#  [3, 'Oil-Fill', 'Electrical-Shock', 'Low', 0.75, 0.01],
#  [3, 'Oil-Fill', 'FallGtm', 'High', 0.1, 0.902],
#  [3, 'Oil-Fill', 'FallGtm', 'Low', 0.9, 0.098],
#  [3, 'Sun-Roof-Housing', 'Chemical-Burn', 'High', 0.2, 0.932],
#  [3, 'Sun-Roof-Housing', 'Chemical-Burn', 'Low', 0.8, 0.068],
#  [3, 'Sun-Roof-Housing', 'Contact-Contusion', 'High', 0.35, 0.024],
#  [3, 'Sun-Roof-Housing', 'Contact-Contusion', 'Low', 0.65, 0.976],
#  [3, 'Sun-Roof-Housing', 'Electrical-Burn', 'High', 0.4, 0.04],
#  [3, 'Sun-Roof-Housing', 'Electrical-Burn', 'Low', 0.6, 0.96],
#  [3, 'Sun-Roof-Housing', 'Electrical-Shock', 'High', 0.25, 0.02],
#  [3, 'Sun-Roof-Housing', 'Electrical-Shock', 'Low', 0.75, 0.98],
#  [3, 'Sun-Roof-Housing', 'FallGtm', 'High', 0.4, 0.03],
#  [3, 'Sun-Roof-Housing', 'FallGtm', 'Low', 0.6, 0.97],
#  [4, 'Accel-Pedal', 'Chemical-Burn', 'High', 0.85, 0.9533],
#  [4, 'Accel-Pedal', 'Chemical-Burn', 'Low', 0.15, 0.0467],
#  [4, 'Accel-Pedal', 'Contact-Contusion', 'High', 0.9, 0.98],
#  [4, 'Accel-Pedal', 'Contact-Contusion', 'Low', 0.1, 0.02],
#  [4, 'Accel-Pedal', 'Electrical-Burn', 'High', 0.15, 0.87],
#  [4, 'Accel-Pedal', 'Electrical-Burn', 'Low', 0.85, 0.13],
#  [4, 'Accel-Pedal', 'Electrical-Shock', 'High', 0.25, 0.88],
#  [4, 'Accel-Pedal', 'Electrical-Shock', 'Low', 0.75, 0.12],
#  [4, 'Accel-Pedal', 'FallGtm', 'High', 0.15, 0.856],
#  [4, 'Accel-Pedal', 'FallGtm', 'Low', 0.85, 0.14400000000000002],
#  [4, 'Door-Mount', 'Chemical-Burn', 'High', 0.2, 0.88],
#  [4, 'Door-Mount', 'Chemical-Burn', 'Low', 0.8, 0.12],
#  [4, 'Door-Mount', 'Contact-Contusion', 'High', 0.9, 0.9456],
#  [4, 'Door-Mount', 'Contact-Contusion', 'Low', 0.1, 0.054400000000000004],
#  [4, 'Door-Mount', 'Electrical-Burn', 'High', 1.0, 1.0],
#  [4, 'Door-Mount', 'Electrical-Burn', 'Low', 0.0, 0.0],
#  [4, 'Door-Mount', 'Electrical-Shock', 'High', 0.85, 0.83],
#  [4, 'Door-Mount', 'Electrical-Shock', 'Low', 0.15, 0.17],
#  [4, 'Door-Mount', 'FallGtm', 'High', 1.0, 1.0],
#  [4, 'Door-Mount', 'FallGtm', 'Low', 0.0, 0.0],
#  [4, 'Engine-Mount', 'Chemical-Burn', 'High', 0.05, 0.94],
#  [4, 'Engine-Mount', 'Chemical-Burn', 'Low', 0.95, 0.06],
#  [4, 'Engine-Mount', 'Contact-Contusion', 'High', 0.1, 0.96],
#  [4, 'Engine-Mount', 'Contact-Contusion', 'Low', 0.9, 0.04],
#  [4, 'Engine-Mount', 'Electrical-Burn', 'High', 0.05, 0.95],
#  [4, 'Engine-Mount', 'Electrical-Burn', 'Low', 0.95, 0.05],
#  [4, 'Engine-Mount', 'Electrical-Shock', 'High', 0.1, 0.96],
#  [4, 'Engine-Mount', 'Electrical-Shock', 'Low', 0.9, 0.04],
#  [4, 'Engine-Mount', 'FallGtm', 'High', 0.03, 0.93],
#  [4, 'Engine-Mount', 'FallGtm', 'Low', 0.97, 0.07],
#  [4, 'Engine-Wiring', 'Chemical-Burn', 'High', 0.1, 0.98],
#  [4, 'Engine-Wiring', 'Chemical-Burn', 'Low', 0.9, 0.02],
#  [4, 'Engine-Wiring', 'Contact-Contusion', 'High', 0.91, 0.02],
#  [4, 'Engine-Wiring', 'Contact-Contusion', 'Low', 0.09, 0.98],
#  [4, 'Engine-Wiring', 'Electrical-Burn', 'High', 0.94, 0.03],
#  [4, 'Engine-Wiring', 'Electrical-Burn', 'Low', 0.06, 0.97],
#  [4, 'Engine-Wiring', 'Electrical-Shock', 'High', 0.9, 0.005],
#  [4, 'Engine-Wiring', 'Electrical-Shock', 'Low', 0.1, 0.995],
#  [4, 'Engine-Wiring', 'FallGtm', 'High', 0.95, 0.01],
#  [4, 'Engine-Wiring', 'FallGtm', 'Low', 0.05, 0.99],
#  [4, 'Oil-Fill', 'Chemical-Burn', 'High', 0.89, 0.92],
#  [4, 'Oil-Fill', 'Chemical-Burn', 'Low', 0.11, 0.08],
#  [4, 'Oil-Fill', 'Contact-Contusion', 'High', 0.95, 0.934],
#  [4, 'Oil-Fill', 'Contact-Contusion', 'Low', 0.05, 0.066],
#  [4, 'Oil-Fill', 'Electrical-Burn', 'High', 0.9, 0.01],
#  [4, 'Oil-Fill', 'Electrical-Burn', 'Low', 0.1, 0.99],
#  [4, 'Oil-Fill', 'Electrical-Shock', 'High', 0.95, 0.121],
#  [4, 'Oil-Fill', 'Electrical-Shock', 'Low', 0.05, 0.879],
#  [4, 'Oil-Fill', 'FallGtm', 'High', 0.9, 0.11],
#  [4, 'Oil-Fill', 'FallGtm', 'Low', 0.1, 0.89],
#  [4, 'Sun-Roof-Housing', 'Chemical-Burn', 'High', 0.95, 0.113],
#  [4, 'Sun-Roof-Housing', 'Chemical-Burn', 'Low', 0.05, 0.887],
#  [4, 'Sun-Roof-Housing', 'Contact-Contusion', 'High', 0.02, 0.31],
#  [4, 'Sun-Roof-Housing', 'Contact-Contusion', 'Low', 0.98, 0.69],
#  [4, 'Sun-Roof-Housing', 'Electrical-Burn', 'High', 0.05, 0.32],
#  [4, 'Sun-Roof-Housing', 'Electrical-Burn', 'Low', 0.95, 0.68],
#  [4, 'Sun-Roof-Housing', 'Electrical-Shock', 'High', 0.01, 0.17],
#  [4, 'Sun-Roof-Housing', 'Electrical-Shock', 'Low', 0.99, 0.83],
#  [4, 'Sun-Roof-Housing', 'FallGtm', 'High', 0.05, 0.188],
#  [4, 'Sun-Roof-Housing', 'FallGtm', 'Low', 0.95, 0.812],
#  [5, 'Accel-Pedal', 'Chemical-Burn', 'High', 0.83, 0.96],
#  [5, 'Accel-Pedal', 'Chemical-Burn', 'Low', 0.17, 0.04],
#  [5, 'Accel-Pedal', 'Contact-Contusion', 'High', 0.9, 0.987],
#  [5, 'Accel-Pedal', 'Contact-Contusion', 'Low', 0.1, 0.013000000000000001],
#  [5, 'Accel-Pedal', 'Electrical-Burn', 'High', 0.82, 0.1],
#  [5, 'Accel-Pedal', 'Electrical-Burn', 'Low', 0.18, 0.9],
#  [5, 'Accel-Pedal', 'Electrical-Shock', 'High', 0.8, 0.111],
#  [5, 'Accel-Pedal', 'Electrical-Shock', 'Low', 0.2, 0.889],
#  [5, 'Accel-Pedal', 'FallGtm', 'High', 0.75, 0.13],
#  [5, 'Accel-Pedal', 'FallGtm', 'Low', 0.25, 0.87],
#  [5, 'Door-Mount', 'Chemical-Burn', 'High', 0.8, 0.147],
#  [5, 'Door-Mount', 'Chemical-Burn', 'Low', 0.2, 0.853],
#  [5, 'Door-Mount', 'Contact-Contusion', 'High', 0.91, 0.9],
#  [5, 'Door-Mount', 'Contact-Contusion', 'Low', 0.09, 0.1],
#  [5, 'Door-Mount', 'Electrical-Burn', 'High', 1.0, 1.0],
#  [5, 'Door-Mount', 'Electrical-Burn', 'Low', 0.0, 0.0],
#  [5, 'Door-Mount', 'Electrical-Shock', 'High', 0.9234, 0.899],
#  [5, 'Door-Mount', 'Electrical-Shock', 'Low', 0.0766, 0.10099999999999999],
#  [5, 'Door-Mount', 'FallGtm', 'High', 1.0, 1.0],
#  [5, 'Door-Mount', 'FallGtm', 'Low', 0.0, 0.0],
#  [5, 'Engine-Mount', 'Chemical-Burn', 'High', 0.8231999999999999, 0.02],
#  [5, 'Engine-Mount', 'Chemical-Burn', 'Low', 0.17679999999999998, 0.98],
#  [5, 'Engine-Mount', 'Contact-Contusion', 'High', 0.9, 0.03],
#  [5, 'Engine-Mount', 'Contact-Contusion', 'Low', 0.1, 0.97],
#  [5, 'Engine-Mount', 'Electrical-Burn', 'High', 0.8723000000000001, 0.01],
#  [5, 'Engine-Mount', 'Electrical-Burn', 'Low', 0.1277, 0.99],
#  [5, 'Engine-Mount', 'Electrical-Shock', 'High', 0.9, 0.01],
#  [5, 'Engine-Mount', 'Electrical-Shock', 'Low', 0.1, 0.99],
#  [5, 'Engine-Mount', 'FallGtm', 'High', 0.8334, 0.03445],
#  [5, 'Engine-Mount', 'FallGtm', 'Low', 0.1666, 0.96555],
#  [5, 'Engine-Wiring', 'Chemical-Burn', 'High', 0.9, 0.03445],
#  [5, 'Engine-Wiring', 'Chemical-Burn', 'Low', 0.1, 0.96555],
#  [5,
#   'Engine-Wiring',
#   'Contact-Contusion',
#   'High',
#   0.034300000000000004,
#   0.903],
#  [5,
#   'Engine-Wiring',
#   'Contact-Contusion',
#   'Low',
#   0.9656999999999999,
#   0.09699999999999999],
#  [5, 'Engine-Wiring', 'Electrical-Burn', 'High', 0.1, 1.0],
#  [5, 'Engine-Wiring', 'Electrical-Burn', 'Low', 0.9, 0.0],
#  [5, 'Engine-Wiring', 'Electrical-Shock', 'High', 0.023, 0.983],
#  [5, 'Engine-Wiring', 'Electrical-Shock', 'Low', 0.977, 0.017],
#  [5, 'Engine-Wiring', 'FallGtm', 'High', 0.05, 1.0],
#  [5, 'Engine-Wiring', 'FallGtm', 'Low', 0.95, 0.0],
#  [5, 'Oil-Fill', 'Chemical-Burn', 'High', 0.8740000000000001, 0.97],
#  [5, 'Oil-Fill', 'Chemical-Burn', 'Low', 0.126, 0.03],
#  [5, 'Oil-Fill', 'Contact-Contusion', 'High', 0.9, 0.9854299999999999],
#  [5, 'Oil-Fill', 'Contact-Contusion', 'Low', 0.1, 0.014569999999999998],
#  [5, 'Oil-Fill', 'Electrical-Burn', 'High', 0.222, 0.95],
#  [5, 'Oil-Fill', 'Electrical-Burn', 'Low', 0.778, 0.05],
#  [5, 'Oil-Fill', 'Electrical-Shock', 'High', 0.25, 0.99434],
#  [5, 'Oil-Fill', 'Electrical-Shock', 'Low', 0.75, 0.005660000000000001],
#  [5, 'Oil-Fill', 'FallGtm', 'High', 0.17, 0.93],
#  [5, 'Oil-Fill', 'FallGtm', 'Low', 0.83, 0.07],
#  [5, 'Sun-Roof-Housing', 'Chemical-Burn', 'High', 0.2, 0.94],
#  [5, 'Sun-Roof-Housing', 'Chemical-Burn', 'Low', 0.8, 0.06],
#  [5,
#   'Sun-Roof-Housing',
#   'Contact-Contusion',
#   'High',
#   0.35678000000000004,
#   0.01],
#  [5, 'Sun-Roof-Housing', 'Contact-Contusion', 'Low', 0.64322, 0.99],
#  [5, 'Sun-Roof-Housing', 'Electrical-Burn', 'High', 0.4, 0.02],
#  [5, 'Sun-Roof-Housing', 'Electrical-Burn', 'Low', 0.6, 0.98],
#  [5, 'Sun-Roof-Housing', 'Electrical-Shock', 'High', 0.32356, 0.01],
#  [5, 'Sun-Roof-Housing', 'Electrical-Shock', 'Low', 0.6764399999999999, 0.99],
#  [5, 'Sun-Roof-Housing', 'FallGtm', 'High', 0.4, 0.02],
#  [5, 'Sun-Roof-Housing', 'FallGtm', 'Low', 0.6, 0.98]]

# %%
pgmpyToGraphCPD(carModel)
