# %%
import os
from typing import *


os.getcwd()
# Setting the baseline:
os.chdir('/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP')


curPath: str = os.getcwd() + "/src/PgmpyStudy/"

dataPath: str = curPath + "data/"


print("curPath = ", curPath, "\n")
print("dataPath = ", dataPath, "\n")
# Out:
# curPath =  /development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/PgmpyStudy/
#
# dataPath =  /development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/PgmpyStudy/data/

# %%
import sys
# Making files in utils folder visible here: to import my local print functions for nn.Module objects
sys.path.append(os.getcwd() + "/src/utils/")
# For being able to import files within CausalNex folder
sys.path.append(curPath)
sys.path.append(curPath + 'fonts/')

sys.path
# Out:
# ['/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/PgmpyStudy',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python37.zip',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7/lib-dynload',
#  '',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7/site-packages',
#  '/development/bin/python/conda3_ana/envs/pybayesian_env/lib/python3.7/site-packages/IPython/extensions',
#  '/home/statisticallyfit/.ipython',
#  '/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/utils/',
#  '/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/PgmpyStudy/',
#  '/development/projects/statisticallyfit/github/learningmathstat/PythonNeuralNetNLP/src/PgmpyStudy/fonts/']

# %% [markdown]
# Fitting node states, using the input data:

# %%
import pandas as pd
from pandas.core.frame import DataFrame

from src.utils.DataUtil import *

CPD_workCapacity: DataFrame = pd.read_csv(dataPath + 'cpd_workcapacity.csv', delimiter =',') #, keep_default_na=False)
#inputData.columns # see column names
CPD_workCapacity = cleanData(CPD_workCapacity.dropna())  # remove the NA rows (which are the empty ones) and clean the whitespaces

CPD_workCapacity
# Out:
#     Time (Days in Week) Exertion Level Experience Level Training Level  \
# 0                     1            Low              Low            Low
# 1                     1            Low              Low           High
# 2                     1            Low             High            Low
# 3                     1            Low             High           High
# 4                     1           High              Low            Low
# 5                     1           High              Low           High
# 6                     1           High             High            Low
# 7                     1           High             High           High
# 8                     2            Low              Low            Low
# 9                     2            Low              Low           High
# 10                    2            Low             High            Low
# 11                    2            Low             High           High
# 12                    2           High              Low            Low
# 13                    2           High              Low           High
# 14                    2           High             High            Low
# 15                    2           High             High           High
# 16                    3            Low              Low            Low
# 17                    3            Low              Low           High
# 18                    3            Low             High            Low
# 19                    3            Low             High           High
# 20                    3           High              Low            Low
# 21                    3           High              Low           High
# 22                    3           High             High            Low
# 23                    3           High             High           High
# 24                    4            Low              Low            Low
# 25                    4            Low              Low           High
# 26                    4            Low             High            Low
# 27                    4            Low             High           High
# 28                    4           High              Low            Low
# 29                    4           High              Low           High
# 30                    4           High             High            Low
# 31                    4           High             High           High
# 32                    5            Low              Low            Low
# 33                    5            Low              Low           High
# 34                    5            Low             High            Low
# 35                    5            Low             High           High
# 36                    5           High              Low            Low
# 37                    5           High              Low           High
# 38                    5           High             High            Low
# 39                    5           High             High           High
#
#        Low    High
# 0    0.014  99.986
# 1   20.000  80.000
# 2   15.000  85.000
# 3    2.000  98.000
# 4   90.000  10.000
# 5   60.000  40.000
# 6   19.000  81.000
# 7   11.000  89.000
# 8   31.000  69.000
# 9   21.000  79.000
# 10  15.000  85.000
# 11   2.000  98.000
# 12  90.000  10.000
# 13  61.000  39.000
# 14  11.000  89.000
# 15  12.000  88.000
# 16  31.000  69.000
# 17  21.000  79.000
# 18  16.000  84.000
# 19   3.000  97.000
# 20  91.000   9.000
# 21  60.000  40.000
# 22  16.000  84.000
# 23  15.000  85.000
# 24  32.000  68.000
# 25  22.000  78.000
# 26  16.000  84.000
# 27   3.000  97.000
# 28  91.000   9.000
# 29  62.000  38.000
# 30  19.000  81.000
# 31  13.000  87.000
# 32  33.000  67.000
# 33  25.000  75.000
# 34  17.000  83.000
# 35   4.000  96.000
# 36  92.000   8.000
# 37  69.000  31.000
# 38  18.000  82.000
# 39  17.000  83.000

# %%
CPD_exertionLevel: DataFrame = cleanData(pd.read_csv(dataPath + 'cpd_exertion_experience_training.csv', delimiter =',').dropna())
CPD_experienceLevel = CPD_exertionLevel.copy()
CPD_trainingLevel = CPD_exertionLevel.copy()

CPD_exertionLevel
# Out:
#    Low  High
# 0   50    50

# %%
CPD_injuryType: DataFrame = cleanData(pd.read_csv(dataPath + 'cpd_injurytype.csv', delimiter =',').dropna())

CPD_injuryType
# Out:
#         Process Type           Uses Op  Chemical-Burn  Electrical-Burn  \
# 0        Accel-Pedal          Forklift           20.0             20.0
# 1        Accel-Pedal  Front-Right-Door           20.0             20.0
# 2        Accel-Pedal               Oil           20.0             20.0
# 3        Accel-Pedal         Power-Gun            1.0             40.0
# 4         Door-Mount          Forklift            1.0              8.0
# 5         Door-Mount  Front-Right-Door            1.0              7.0
# 6         Door-Mount               Oil           43.0             33.0
# 7         Door-Mount         Power-Gun            2.5              2.5
# 8       Engine-Mount          Forklift            1.0              8.0
# 9       Engine-Mount  Front-Right-Door            1.0              8.0
# 10      Engine-Mount               Oil           22.0             33.0
# 11      Engine-Mount         Power-Gun            5.0             35.0
# 12     Engine-Wiring          Forklift            3.0              8.0
# 13     Engine-Wiring  Front-Right-Door            1.0              8.0
# 14     Engine-Wiring               Oil           22.0             33.0
# 15     Engine-Wiring         Power-Gun            5.0             35.0
# 16          Oil-Fill          Forklift            0.0              1.0
# 17          Oil-Fill  Front-Right-Door            0.0             10.0
# 18          Oil-Fill               Oil            0.0             50.0
# 19          Oil-Fill         Power-Gun            0.0             40.0
# 20  Sun-Roof-Housing          Forklift            0.0              0.0
# 21  Sun-Roof-Housing  Front-Right-Door            0.0              0.0
# 22  Sun-Roof-Housing               Oil           20.0             30.0
# 23  Sun-Roof-Housing         Power-Gun           20.0             30.0
#
#     Electrical-Shock  Contact-Contusion  FallGtm
# 0                 20               20.0     20.0
# 1                 20               20.0     20.0
# 2                 20               20.0     20.0
# 3                 57                1.0      1.0
# 4                  1               80.0     10.0
# 5                  2               75.0     15.0
# 6                 22                1.0      1.0
# 7                 90                2.5      2.5
# 8                  1               80.0     10.0
# 9                  1               80.0     10.0
# 10                43                1.0      1.0
# 11                60                0.0      0.0
# 12                 5               79.0      5.0
# 13                 1               80.0     10.0
# 14                45                0.0      0.0
# 15                60                0.0      0.0
# 16                 4               70.0     25.0
# 17                10               80.0      0.0
# 18                50                0.0      0.0
# 19                60                0.0      0.0
# 20                 0               40.0     60.0
# 21                 0               70.0     30.0
# 22                50                0.0      0.0
# 23                50                0.0      0.0

# %%
CPD_processType: DataFrame = cleanData(pd.read_csv(dataPath + 'cpd_processtype.csv', delimiter =',').dropna())
CPD_processType
# Out:
#    Accel-Pedal  Door-Mount  Engine-Mount  Engine-Wiring  Oil-Fill  \
# 0       16.667      16.667        16.667         16.667    16.667
#
#    Sun-Roof-Housing
# 0            16.667

# %%
CPD_time: DataFrame = cleanData(pd.read_csv(dataPath + 'cpd_time.csv', delimiter =',').dropna())

CPD_time
# Out:
#     1   2   3   4   5
# 0  20  20  20  20  20

# %%
CPD_usesop: DataFrame = cleanData(pd.read_csv(dataPath + 'cpd_usesop.csv', delimiter =',').dropna())

CPD_usesop
# Out:
#        Process Type  Forklift  Front-Right-Door  Oil  Power-Gun
# 0       Accel-Pedal         1                 7    2         90
# 1        Door-Mount         4                90    1          5
# 2      Engine-Mount        95                 1    1          3
# 3     Engine-Wiring         1                 1    1         97
# 4          Oil-Fill         0                 0  100          0
# 5  Sun-Roof-Housing        94                 1    3          2

# %%
CPD_absentee: DataFrame = cleanData(pd.read_csv(dataPath + 'cpd_absentee.csv', delimiter =',').dropna())
CPD_absentee
# Out:
#      Time (Days in Week)      Process Type        Injury Type Work Capacity  \
# 0                      1       Accel-Pedal      Chemical-Burn           Low
# 1                      1       Accel-Pedal      Chemical-Burn          High
# 2                      1       Accel-Pedal    Electrical-Burn           Low
# 3                      1       Accel-Pedal    Electrical-Burn          High
# 4                      1       Accel-Pedal   Electrical-Shock           Low
# ..                   ...               ...                ...           ...
# 295                    5  Sun-Roof-Housing   Electrical-Shock          High
# 296                    5  Sun-Roof-Housing  Contact-Contusion           Low
# 297                    5  Sun-Roof-Housing  Contact-Contusion          High
# 298                    5  Sun-Roof-Housing            FallGtm           Low
# 299                    5  Sun-Roof-Housing            FallGtm          High
#
#       Low  High
# 0    70.0  30.0
# 1    90.0  10.0
# 2    60.0  40.0
# 3    80.0  20.0
# 4    70.0  30.0
# ..    ...   ...
# 295  94.0   6.0
# 296   1.0  99.0
# 297   2.0  98.0
# 298   1.0  99.0
# 299   2.0  98.0
#
# [300 rows x 6 columns]
